# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
import glob

# Get a list of all files in the folder
all_files = glob.glob('./all_seasons_data/2017-2018/gw_0/*.csv')

# Read the first file into a DataFrame
df = pd.read_csv(all_files[0])
df['unique_id'] = df['player'] + '_' + df['Equipo']
df.drop_duplicates(subset='unique_id', inplace=True)
# For each remaining file
for file in all_files[1:]:
    # Read the file into a DataFrame
    df_other = pd.read_csv(file)
    if 'goalkeepers' in file:
        continue
    df_other['unique_id'] = df_other['player'] + '_' + df_other['Equipo']
    df_other.drop_duplicates(subset='unique_id', inplace=True)
    # Merge the DataFrames on the unique identifier
    df1 = pd.merge(df, df_other, on='unique_id',how='inner',suffixes=('','_remove'))

# Print the first 5 rows of the merged DataFrame
df1.head()
# Out:
#                   player  shirtnumber nationality position     age  minutes  \
# 0  Miguel Ángel Guerrero            9      es ESP       FW  27-037       90
# 1              Alexander           11      ar ARG       LW  28-309       90
# 2             Omar Ramos           23      es ESP       RW  29-204       64
# 3             Erik Morán            4      es ESP       DM  26-085       26
# 4           Javier Eraso           17      es ESP    AM,RW  27-149       69
#
#    tackles  tackles_won  tackles_def_3rd  tackles_mid_3rd  ...  passes  \
# 0        1            1                0                0  ...      26
# 1        1            1                0                1  ...      27
# 2        2            2                1                0  ...      23
# 3        0            0                0                0  ...      14
# 4        2            1                1                1  ...      23
#
#    passes_pct  progressive_passes  carries  progressive_carries  take_ons  \
# ...

# %%
def mergeGw(season, folder_path,rounds):
    for i in range(rounds):
        all_files = glob.glob(os.path.join(folder_path, f"{season}/gw_{i}/*.csv"))
        df = pd.read_csv(all_files[0])
        df['unique_id'] = df['player'] + '_' + df['Equipo']
        data_frames = []
        for file in all_files[1:]:
            # Read the file into a DataFrame
            df_other = pd.read_csv(file)
            if 'goalkeepers' in file:
                continue
            df_other['unique_id'] = df_other['player'] + '_' + df_other['Equipo']
            df = pd.merge(df, df_other, on=['unique_id'],how='inner')
            df = df.reset_index(drop=True)
        data_frames.append(df)
        data1 = pd.concat(data_frames, axis=0)
        df.to_csv('jh2a2.csv')
mergeGw('2017-2018', './all_seasons_data/', 1)

# %%
df4.head()
# Out:
#                   player  shirtnumber nationality position     age  minutes  \
# 0  Miguel Ángel Guerrero            9      es ESP       FW  27-037       90
# 1              Alexander           11      ar ARG       LW  28-309       90
# 2             Omar Ramos           23      es ESP       RW  29-204       64
# 3             Erik Morán            4      es ESP       DM  26-085       26
# 4           Javier Eraso           17      es ESP    AM,RW  27-149       69
#
#    tackles  tackles_won  tackles_def_3rd  tackles_mid_3rd  ...  pens_made  \
# 0        1            1                0                0  ...        NaN
# 1        1            1                0                1  ...        NaN
# 2        2            2                1                0  ...        NaN
# 3        0            0                0                0  ...        NaN
# 4        2            1                1                1  ...        NaN
#
# ...

# %%
frames = [df1,df2]
df = pd.concat(frames)

# %%
df1.to_csv('test.csv')

# %%
df.columns
# Out:
# Index(['player', 'shirtnumber', 'nationality', 'position', 'age', 'minutes',
#        'tackles', 'tackles_won', 'tackles_def_3rd', 'tackles_mid_3rd',
#        'tackles_att_3rd', 'challenge_tackles', 'challenges',
#        'challenge_tackles_pct', 'challenges_lost', 'blocks', 'blocked_shots',
#        'blocked_passes', 'interceptions', 'tackles_interceptions',
#        'clearances', 'errors', 'Matchweek', 'Season', 'Equipo', 'unique_id',
#        'player_remove', 'shirtnumber_remove', 'nationality_remove',
#        'position_remove', 'age_remove', 'minutes_remove', 'goals', 'assists',
#        'pens_made', 'pens_att', 'shots', 'shots_on_target', 'cards_yellow',
#        'cards_red', 'touches', 'tackles_remove', 'interceptions_remove',
#        'blocks_remove', 'xg', 'npxg', 'xg_assist', 'sca', 'gca',
#        'passes_completed', 'passes', 'passes_pct', 'progressive_passes',
#        'carries', 'progressive_carries', 'take_ons', 'take_ons_won',
# ...

# %%
df_players = df[df['position'] != 'GK']

# %%
df_players['xg']
# Out:
# 0      0.3
# 1      0.1
# 2      0.0
# 3      0.0
# 4      0.0
#       ...
# 272    0.0
# 273    0.0
# 274    0.0
# 275    0.0
# 276    0.0
# Name: xg, Length: 256, dtype: float64

# %%
mergeGw('2017-2018', './all_seasons_data/',0)
# Out:
# Succesfully merged into season 2017-2018
